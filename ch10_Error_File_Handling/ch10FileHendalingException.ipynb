# %%
l1: list[int] = [1,2,3]
try:
  print(3/1)
  # print(xyz)
  print(l1[3])
except(ZeroDivisionError):
  print("You are trying to devide by zeero!")
except(NameError):
  print("Name Error")
except(IndexError):
  print("Index Error!")
# Out:
# 3.0
# Index Error!

# %%
try:
  print(3/0)
except Exception as e:
  print(f"Some thing went wrong!\n", e)
# Out:
# Some thing went wrong!
#  division by zero

# %% [markdown]
# File Handling

# %%
with open("./pi_digits.txt") as pdt:
  print(pdt.read())
# Out:
# 3.1415926535
#  8979323846
#  2643383279

# %%
with open("./pi_digits.txt", "r") as pdt:
  # pdt.write("\t6969")
  pdt.seek(0)
  print(pdt.read())
# Out:
# 123
# 123	6969	6969

# %%
import pandas as pd

df : pd.DataFrame = pd.read_csv("./csv.csv")

df
# Out:
#    id     name       education
# 0   1     Asad            BSSE
# 1   2  Subhani  PIAIC Graduate

# %%
import pandas as pd

df : pd.DataFrame = pd.read_excel("./demo.xlsx")

df
# Out:
#    id     name   education
# 0   1     Asad        BSSE
# 1   2  Jaweria  PIAIC Grad
# 2   3    Adeel  PIAIC Grad

# %%
# !pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/50/ce/a6bc93f7a44dd1fd23698698e369e141f4f24e7098d0a5937808afee3f5e/matplotlib-3.8.3-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/8e/ae/a6353db548bff1a592b85ae6bb80275f0a51dc25a0410d059e5b33183e36/contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/28/27/42f5cac9f5ee15ab65b3fd939e37a115a0a5e367fcabde5b901599daa85a/fonttools-4.49.0-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread("image.jpg")
plt.imshow(img)
